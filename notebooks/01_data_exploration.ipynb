# %%
import pandas as pd
import numpy as np

# %%
excel_file = pd.ExcelFile("../data/raw/College-labor-data.xlsx")
excel_file.sheet_names
# Out:
# ['Cover Sheet', 'unemployed', 'underemployed', 'wages', 'outcomes by major']

# %%
nyfed = pd.read_excel("../data/raw/College-labor-data.xlsx",
                      sheet_name='outcomes by major',
                      header=10)
nyfed.head(20)
# Out:
#                                Major  Unemployment Rate  Underemployment Rate  \
# 0                        Agriculture              1.395                57.098
# 1          Animal and Plant Sciences              2.539                53.538
# 2              Environmental Studies              6.307                50.523
# 3                       Architecture              6.844                25.669
# 4                     Ethnic Studies              4.856                49.554
# 5                     Communications              3.856                53.028
# 6                         Journalism              2.319                43.256
# 7                         Mass Media              5.158                52.125
# 8   Advertising and Public Relations              5.677                38.076
# 9   Information Systems & Management              5.979                25.637
# 10                  Computer Science              6.992                19.127
# ...

# %%
nyfed.shape
# Out:
# (74, 6)

# %%
nyfed.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Major                       74 non-null     str
#  1   Unemployment Rate           74 non-null     float64
#  2   Underemployment Rate        74 non-null     float64
#  3   Median Wage Early Career    74 non-null     int64
#  4   Median Wage Mid-Career      74 non-null     int64
#  5   Share with Graduate Degree  74 non-null     float64
# dtypes: float64(3), int64(2), str(1)
# memory usage: 3.6 KB

# %%
nyfed.describe()
# Out:
#        Unemployment Rate  Underemployment Rate  Median Wage Early Career  \
# count          74.000000             74.000000                 74.000000
# mean            4.086541             38.479054              56974.324324
# std             1.774307             13.908829              12973.134102
# min             0.739000             12.781000              40000.000000
# 25%             2.568750             26.273250              46825.000000
# 50%             4.181000             42.918000              52000.000000
# 75%             5.149250             49.264250              66500.000000
# max             7.922000             65.790000              90000.000000
#
#        Median Wage Mid-Career  Share with Graduate Degree
# count               74.000000                   74.000000
# mean             87216.216216                   41.308514
# std              19106.242450                   13.771780
# min              52000.000000                   12.214000
# ...

# %%
nyfed["Major"].tolist()
# Out:
# ['Agriculture',
#  'Animal and Plant Sciences',
#  'Environmental Studies',
#  'Architecture',
#  'Ethnic Studies',
#  'Communications',
#  'Journalism',
#  'Mass Media',
#  'Advertising and Public Relations',
#  'Information Systems & Management',
#  'Computer Science',
#  'General Education',
#  'Early Childhood Education',
#  'Elementary Education',
#  'Secondary Education',
#  'Special Education',
#  'Miscellaneous Education',
#  'General Engineering',
#  'Aerospace Engineering',
#  'Chemical Engineering',
#  'Civil Engineering',
#  'Computer Engineering',
#  'Electrical Engineering',
#  'Industrial Engineering',
#  'Mechanical Engineering',
#  'Miscellaneous Engineering',
#  'Foreign Language',
#  'Family and Consumer Sciences',
#  'English Language',
#  'Liberal Arts',
#  'Biology',
#  'Biochemistry',
#  'Miscellaneous Biological Science',
#  'Mathematics',
#  'Interdisciplinary Studies',
#  'Nutrition Sciences',
#  'Leisure and Hospitality',
#  'Philosophy',
# ...

# %%
nyfed["Major"].duplicated().sum()
# Out:
# np.int64(0)

# %%
nyfed.sort_values("Unemployment Rate")[["Major", "Unemployment Rate"]]
# Out:
#                       Major  Unemployment Rate
# 15        Special Education              0.739
# 16  Miscellaneous Education              1.089
# 13     Elementary Education              1.180
# 0               Agriculture              1.395
# 26         Foreign Language              1.579
# ..                      ...                ...
# 56          Performing Arts              6.950
# 10         Computer Science              6.992
# 55                Fine Arts              7.655
# 21     Computer Engineering              7.783
# 47             Anthropology              7.922
#
# [74 rows x 2 columns]
